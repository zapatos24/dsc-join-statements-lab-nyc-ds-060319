# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of join statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, you'll use the same Customer Relationship Management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
#Your code here
import sqlite3
conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.
# Hint: join the employees and offices tables.

# %%
#Your code here
c.execute("""select firstName, lastName 
            from employees join offices using(officeCode) 
            where city = 'Boston'""").fetchall()
# Out:
# [('Julie', 'Firrelli'), ('Steve', 'Patterson')]

# %% [markdown]
# ## Do any offices have no employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
#Your code here
c.execute("""select officeCode, count(employeeNumber)
            from offices 
            left join employees
            using(officeCode)
            group by officeCode""").fetchall()
# Out:
# [('1', 6), ('2', 2), ('3', 2), ('4', 5), ('5', 2), ('6', 4), ('7', 2)]

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold

# %%
# Your code here
c.execute("""SELECT DISTINCT productName, lastName, firstName
            FROM employees 
            JOIN customers ON employees.employeeNumber = customers.salesRepEmployeeNumber
            JOIN orders using(customerNumber)
            JOIN orderdetails using(orderNumber)
            JOIN products using(productCode)
            ORDER BY lastName, firstName
            """).fetchall()
# Out:
# [('1952 Alpine Renault 1300', 'Bondur', 'Loui'),
#  ('1962 LanciaA Delta 16V', 'Bondur', 'Loui'),
#  ('1958 Setra Bus', 'Bondur', 'Loui'),
#  ('1940 Ford Pickup Truck', 'Bondur', 'Loui'),
#  ('1926 Ford Fire Engine', 'Bondur', 'Loui'),
#  ('1940s Ford truck', 'Bondur', 'Loui'),
#  ('1939 Cadillac Limousine', 'Bondur', 'Loui'),
#  ('1962 Volkswagen Microbus', 'Bondur', 'Loui'),
#  ('1980’s GM Manhattan Express', 'Bondur', 'Loui'),
#  ('1996 Peterbilt 379 Stake Bed with Outrigger', 'Bondur', 'Loui'),
#  ('1982 Camaro Z28', 'Bondur', 'Loui'),
#  ('2001 Ferrari Enzo', 'Bondur', 'Loui'),
#  ('1969 Corvair Monza', 'Bondur', 'Loui'),
#  ('1969 Ford Falcon', 'Bondur', 'Loui'),
#  ('1903 Ford Model A', 'Bondur', 'Loui'),
#  ('Collectable Wooden Train', 'Bondur', 'Loui'),
#  ('1904 Buick Runabout', 'Bondur', 'Loui'),
#  ('18th century schooner', 'Bondur', 'Loui'),
#  ('1912 Ford Model T Delivery Wagon', 'Bondur', 'Loui'),
#  ('1962 City of Detroit Streetcar', 'Bondur', 'Loui'),
# ...

# %% [markdown]
# ## Level Up: Display the Number of Products each employee has sold

# %%
#Your code here
c.execute("""SELECT employeeNumber, lastName, firstName, sum(quantityOrdered) AS products_sold
            FROM employees 
            JOIN customers ON employees.employeeNumber = customers.salesRepEmployeeNumber
            JOIN orders using(customerNumber)
            JOIN orderdetails using(orderNumber)
            GROUP BY employeeNumber
            """).fetchall()
# Out:
# [('1165', 'Jennings', 'Leslie', 11854),
#  ('1166', 'Thompson', 'Leslie', 4056),
#  ('1188', 'Firrelli', 'Julie', 4227),
#  ('1216', 'Patterson', 'Steve', 5561),
#  ('1286', 'Tseng', 'Foon Yue', 5016),
#  ('1323', 'Vanauf', 'George', 7423),
#  ('1337', 'Bondur', 'Loui', 6186),
#  ('1370', 'Hernandez', 'Gerard', 14231),
#  ('1401', 'Castillo', 'Pamela', 9290),
#  ('1501', 'Bott', 'Larry', 8205),
#  ('1504', 'Jones', 'Barry', 7486),
#  ('1611', 'Fixter', 'Andy', 6246),
#  ('1612', 'Marsh', 'Peter', 6632),
#  ('1621', 'Nishi', 'Mami', 4923),
#  ('1702', 'Gerard', 'Martin', 4180)]

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use join statements, along with leveraging your foreign keys knowledge!
